# %%
from bertopic import BERTopic
import pandas as pd
import numpy as np
import time

# %% [markdown]
# # 1. Topic Modelling using BERTopic

# %%
df = pd.read_csv("../data/cleaned/cleaned_reviews.csv")
embeddings = np.load("../data/cleaned/sentence_embeddings.npy")

# %%
df_copy = df.copy()

# %%
len(df)
# Out:
# 30157

# %%
embeddings.shape[0]
# Out:
# 30157

# %%
start = time.time()
topic_model = BERTopic(min_topic_size=50,language='english')
topics,probs = topic_model.fit_transform(df['text_clean_full'].tolist(),embeddings=embeddings)  
end = time.time()

# %%
print(f"Number of topics: {len(topic_model.get_topic_info())}")
print(f"Time taken: {(end-start):.2f} seconds")
# Out:
# Number of topics: 77
# Time taken: 40.83 seconds

# %%
topic_info = topic_model.get_topic_info()
print(topic_info.head(20))
# Out:
#     Topic  Count                                   Name  \
# 0      -1  11173                  -1_the_case_screen_it
# 1       0   3540           0_charge_charger_charging_it
# 2       1   1400                 1_watch_band_wrist_the
# 3       2   1094                     2_phone_to_and_sim
# 4       3    750  3_bubbles_protector_screen_protectors
# 5       4    545      4_fingerprint_reader_finger_print
# 6       5    529             5_cards_card_wallet_credit
# 7       6    510           6_broke_broken_after_product
# 8       7    465           7_buttons_button_volume_case
# 9       8    417                8_stylus_pen_tip_pencil
# 10      9    394          9_working_stopped_worked_work
# 11     10    358             10_stick_stay_adhesive_off
# 12     11    332                 11_fit_phone_didnt_did
# 13     12    321                   12_color_case_the_is
# 14     13    309       13_case_protection_protect_phone
# 15     14    308              14_case_broke_apart_cases
# 16     15    300      15_magnet_magnetic_strong_magnets
# 17     16    300              16_sound_ear_hear_headset
# 18     17    285        17_dash_suction_dashboard_mount
# 19     18    258             18_clip_belt_holster_broke
#
#                                        Representation  \
# 0   [the, case, screen, it, and, to, phone, of, is...
# 1   [charge, charger, charging, it, cable, to, bat...
# 2   [watch, band, wrist, the, it, to, and, my, on,...
# 3   [phone, to, and, sim, is, you, this, the, that...
# 4   [bubbles, protector, screen, protectors, the, ...
# 5   [fingerprint, reader, finger, print, screen, p...
# 6   [cards, card, wallet, credit, case, slots, the...
# 7   [broke, broken, after, product, it, within, mo...
# 8   [buttons, button, volume, case, side, press, t...
# 9   [stylus, pen, tip, pencil, tips, ipad, pens, t...
# 10  [working, stopped, worked, work, months, after...
# 11  [stick, stay, adhesive, off, sticky, doesnt, n...
# 12  [fit, phone, didnt, did, my, not, big, too, fo...
# 13  [color, case, the, is, gold, and, looks, clear...
# 14  [case, protection, protect, phone, is, drop, t...
# 15  [case, broke, apart, cases, this, cheap, it, t...
# 16  [magnet, magnetic, strong, magnets, hold, moun...
# 17  [sound, ear, hear, headset, noise, bluetooth, ...
# 18  [dash, suction, dashboard, mount, windshield, ...
# 19  [clip, belt, holster, broke, the, holder, case...
#
#                                   Representative_Docs
# 0   [there are a lot better options out there i bo...
# 1   [this charger worked great for the first few w...
# 2   [the watch band is nice looking it came with t...
# 3   [ive never had a phone that didnt have some an...
# 4   [i did my homework when searching for this scr...
# 5   [fingerprint didnt work, not impressed at all ...
# 6   [the wallet does not close if you put anything...
# 7                      [it broke, it broke, it broke]
# 8   [did not fit the buttons on the side of the ph...
# 9   [this might work as a stylus pen but useless f...
# 10  [it worked at first then after months it stopp...
# 11  [it doesnt stick, doesnt stick wont stay on, a...
# 12  [did not fit my phone, it didnt fit my phone, ...
# 13  [i purchased this case for my daughters new ro...
# 14  [i guess i did not realize just how little pro...
# 15  [this case broke in two weeks waste of money, ...
# 16  [magnet is not strong enough to hold up phone ...
# 17  [i have only had this since february 2014 and ...
# 18  [purchased this after having a good dashboard ...
# 19  [i like the case but after a while the belt cl...

# %%
start = time.time()
topic_model_v2 = BERTopic(min_topic_size=30,language='english')
topics_v2,probs_v2 = topic_model_v2.fit_transform(df['text_clean_full'].tolist(),embeddings=embeddings)
end = time.time()

# %%
topic_info_v2 = topic_model_v2.get_topic_info()

# %%
print(f"Number of topics: {len(topic_model_v2.get_topic_info())} ")
print(f"Time taken: {(end-start):.2f} seconds")
print(f"Noise cluster size: {topic_info_v2[topic_info_v2['Topic']==-1]['Count'].values[0]}")
# Out:
# Number of topics: 127
# Time taken: 7.20 seconds
# Noise cluster size: 11773

# %%
topic_info_v2 = topic_model_v2.get_topic_info()
print(topic_info_v2.head(20))
# Out:
#     Topic  Count                                    Name  \
# 0      -1  11773                   -1_the_screen_case_it
# 1       0   2695         0_charge_charger_charging_cable
# 2       1    977                      1_phone_sim_to_you
# 3       2    556       2_fingerprint_reader_finger_print
# 4       3    523              3_cards_card_wallet_credit
# 5       4    494            4_broke_broken_after_product
# 6       5    453            5_buttons_button_volume_side
# 7       6    416                 6_stylus_pen_tip_pencil
# 8       7    413           7_working_stopped_worked_work
# 9       8    350                8_case_broke_apart_cases
# 10      9    339   9_protector_cracked_screen_protectors
# 11     10    322       10_magnet_magnetic_strong_magnets
# 12     11    306              11_sound_ear_headset_noise
# 13     12    300         12_protection_protect_case_drop
# 14     13    285              13_watch_face_apple_screen
# 15     14    276                 14_color_case_pink_gold
# 16     15    275              15_clip_belt_holster_broke
# 17     16    253      16_water_waterproof_lifeproof_case
# 18     17    246              17_stand_hold_phone_weight
# 19     18    241  18_bubbles_protector_screen_protectors
#
#                                        Representation  \
# 0   [the, screen, case, it, and, to, of, on, is, t...
# 1   [charge, charger, charging, cable, cord, batte...
# 2   [phone, sim, to, you, and, card, is, apps, thi...
# 3   [fingerprint, reader, finger, print, protector...
# 4   [cards, card, wallet, credit, slots, case, clo...
# 5   [broke, broken, after, product, within, money,...
# 6   [buttons, button, volume, side, case, press, p...
# 7   [stylus, pen, tip, pencil, tips, ipad, pens, w...
# 8   [working, stopped, worked, work, months, after...
# 9   [case, broke, apart, cases, months, very, chea...
# 10  [protector, cracked, screen, protectors, crack...
# 11  [magnet, magnetic, strong, magnets, mount, hol...
# 12  [sound, ear, headset, noise, hear, bluetooth, ...
# 13  [protection, protect, case, drop, phone, dropp...
# 14  [watch, face, apple, screen, on, water, protec...
# 15  [color, case, pink, gold, blue, looks, clear, ...
# 16  [clip, belt, holster, broke, the, holder, case...
# 17  [water, waterproof, lifeproof, case, proof, in...
# 18  [stand, hold, phone, weight, holder, falls, it...
# 19  [bubbles, protector, screen, protectors, air, ...
#
#                                   Representative_Docs
# 0   [i couldnt get the screen protector to fully s...
# 1   [update 62721charger stopped working this past...
# 2   [ive never had a phone that didnt have some an...
# 3   [terrible please pass on these these werent th...
# 4   [super cute but it fades very fast and it does...
# 5                      [it broke, it broke, it broke]
# 6   [i like the style of the case but is hard to p...
# 7   [the stylus tip doesnt last long, not for styl...
# 8   [it was great when it worked after 2 months it...
# 9   [this case doesnt last very long broke after a...
# 10  [i have had my screen protector on for two day...
# 11  [this could have been a good phone mount it ha...
# 12  [if you want a comfortable bluetooth this is f...
# 13  [this is a nicelooking attractive phone case i...
# 14  [i brought a 3 pack for my i phone watch 2 ser...
# 15  [well i absolutely love the color the vibrant ...
# 16  [belt clip broke after a short time, belt clip...
# 17  [i checked out several waterproof cases for th...
# 18  [update i had to knock off stars for this prod...
# 19  [put protector on bubbles never went away we k...

# %%
topic_model.reduce_topics(df['text_clean_full'].tolist(),nr_topics=40)
reduced_info = topic_model.get_topic_info()

# %%
print(f"Number of topics after reduction: {len(reduced_info)}")
print(reduced_info.head(20))
# Out:
# Number of topics after reduction: 40
#     Topic  Count                                    Name  \
# 0      -1  11173                      -1_the_it_and_case
# 1       0   4774                      0_charge_to_it_and
# 2       1   1573          1_screen_protector_the_bubbles
# 3       2   1527                   2_the_cards_it_magnet
# 4       3   1520                        3_case_the_is_it
# 5       4   1478                     4_watch_band_the_it
# 6       5   1086                    5_fit_iphone_not_for
# 7       6    864                6_broke_cracked_it_after
# 8       7    791                      7_stick_dash_to_it
# 9       8    551                 8_screen_cracked_my_the
# 10      9    544           9_working_stopped_work_worked
# 11     10    465           10_buttons_button_case_volume
# 12     11    417                   11_stylus_pen_tip_the
# 13     12    401                   12_sound_hear_ear_the
# 14     13    321                   13_fit_size_wrong_too
# 15     14    237               14_camera_lens_lenses_the
# 16     15    235              15_color_green_yellow_pink
# 17     16    156                16_vent_vents_the_holder
# 18     17    151  17_scratches_scratched_peeling_started
# 19     18    147            18_flimsy_cute_cheap_plastic
#
#                                        Representation  \
# 0   [the, it, and, case, to, screen, phone, of, th...
# 1   [charge, to, it, and, charger, phone, the, thi...
# 2   [screen, protector, the, bubbles, fingerprint,...
# 3   [the, cards, it, magnet, to, phone, ring, and,...
# 4   [case, the, is, it, and, this, phone, to, of, my]
# 5   [watch, band, the, it, to, and, my, wrist, on,...
# 6   [fit, iphone, not, for, phone, it, my, the, do...
# 7   [broke, cracked, it, after, apart, within, wee...
# 8   [stick, dash, to, it, suction, off, dashboard,...
# 9   [screen, cracked, my, the, phone, and, it, pro...
# 10  [working, stopped, work, worked, months, after...
# 11  [buttons, button, case, volume, the, side, to,...
# 12  [stylus, pen, tip, the, pencil, to, tips, ipad...
# 13  [sound, hear, ear, the, is, headset, noise, to...
# 14  [fit, size, wrong, too, didnt, small, not, did...
# 15  [camera, lens, lenses, the, flash, to, it, is,...
# 16  [color, green, yellow, pink, colors, white, no...
# 17  [vent, vents, the, holder, car, to, in, it, cl...
# 18  [scratches, scratched, peeling, started, easil...
# 19  [flimsy, cute, cheap, plastic, but, very, it, ...
#
#                                   Representative_Docs
# 0   [update mine turned a dingy yellow after about...
# 1   [i bought this while i was out of town and i w...
# 2   [i have had quite a bit of experience applying...
# 3   [i will be looking for a different product to ...
# 4   [i bought this two months ago and was initiall...
# 5   [in my opinion the item feels cheap light weig...
# 6   [this case does not fit an iphone x, does not ...
# 7                         [broke, it broke, it broke]
# 8   [im disappointed with this product i bought it...
# 9   [with in 2 days the screen protector cracked a...
# 10  [stopped working, worked great but stopped wor...
# 11  [did not fit the buttons on the side of the ph...
# 12  [the tip of these stylus is huge there is no p...
# 13  [sound quality is decent no one complained abo...
# 14               [it didnt fit, it didnt fit, it fit]
# 15  [happily i was able to pass these lenses along...
# 16  [not a good color, the color is not red is not...
# 17  [would not stay in my air vent, will not stay ...
# 18  [had it for less then 3 months and has scratch...
# 19    [very flimsy, flimsy plastic, cheap and flimsy]

# %%
print(reduced_info)
# Out:
#     Topic  Count                                    Name  \
# 0      -1  11834                        -1_the_it_and_to
# 1       0   2961            0_charge_charger_charging_it
# 2       1   1601                       1_the_cards_it_to
# 3       2   1471                     2_watch_band_the_it
# 4       3   1311                        3_case_the_is_it
# 5       4   1203                      4_phone_to_and_the
# 6       5   1140                  5_fit_iphone_not_phone
# 7       6    891                   6_stick_mount_dash_to
# 8       7    854      7_fingerprint_screen_protector_the
# 9       8    596           8_screen_cracked_my_protector
# 10      9    559             9_broke_cracked_apart_after
# 11     10    546          10_working_stopped_work_worked
# 12     11    542                    11_color_case_the_is
# 13     12    500                   12_sound_hear_ear_the
# 14     13    481           13_buttons_button_case_volume
# 15     14    420                   14_stylus_pen_tip_the
# 16     15    372         15_bubbles_screen_protector_the
# 17     16    322                   16_fit_size_wrong_too
# 18     17    234             17_camera_lens_flash_lenses
# 19     18    218                 18_vent_vents_mount_car
# 20     19    169                   19_work_didnt_did_not
# 21     20    167          20_what_sent_returned_expected
# 22     21    166  21_scratches_scratched_peeling_started
# 23     22    134         22_pop_socket_popsocket_sockets
# 24     23    134               23_flimsy_bulky_too_heavy
# 25     24    126              24_quality_poor_very_cheap
# 26     25    124           25_glass_tempered_plastic_not
# 27     26    122                 26_stars_star_give_zero
# 28     27    120         27_cover_protection_protect_not
# 29     28    108                         28_el_de_la_que
# 30     29    105                       29_good_ok_no_not
# 31     30    104              30_junk_garbage_trash_crap
# 32     31     83                   31_tripod_legs_the_to
# 33     32     77                 32_cute_but_plastic_fur
# 34     33     73                  33_leather_is_not_real
# 35     34     66      34_stones_crystals_rhinestones_off
# 36     35     60               35_last_lasted_didnt_long
# 37     36     58                      36_it_case_and_the
# 38     37     54         37_install_easy_to_installation
# 39     38     51                   38_s10_s21_galaxy_for
#
#                                        Representation  \
# 0   [the, it, and, to, screen, case, of, this, is,...
# 1   [charge, charger, charging, it, to, and, the, ...
# 2   [the, cards, it, to, phone, ring, and, magnet,...
# 3   [watch, band, the, it, to, and, wrist, my, on,...
# 4   [case, the, is, it, this, and, phone, to, wate...
# 5   [phone, to, and, the, is, this, it, you, for, ...
# 6   [fit, iphone, not, phone, for, it, my, case, t...
# 7   [stick, mount, dash, to, suction, it, the, off...
# 8   [fingerprint, screen, protector, the, reader, ...
# 9   [screen, cracked, my, protector, the, phone, a...
# 10  [broke, cracked, apart, after, week, within, i...
# 11  [working, stopped, work, worked, it, after, mo...
# 12  [color, case, the, is, glitter, pink, it, and,...
# 13  [sound, hear, ear, the, bluetooth, to, is, and...
# 14  [buttons, button, case, volume, the, side, to,...
# 15  [stylus, pen, tip, the, pencil, to, tips, ipad...
# 16  [bubbles, screen, protector, the, air, and, pr...
# 17  [fit, size, wrong, too, didnt, small, not, did...
# 18  [camera, lens, flash, lenses, the, pictures, t...
# 19  [vent, vents, mount, car, the, to, holder, in,...
# 20  [work, didnt, did, not, doesnt, does, all, wor...
# 21  [what, sent, returned, expected, back, like, n...
# 22  [scratches, scratched, peeling, started, edges...
# 23  [pop, socket, popsocket, sockets, it, off, and...
# 24  [flimsy, bulky, too, heavy, very, cheap, thin,...
# 25  [quality, poor, very, cheap, made, good, bad, ...
# 26  [glass, tempered, plastic, not, screen, is, th...
# 27  [stars, star, give, zero, could, it, would, be...
# 28  [cover, protection, protect, not, thin, it, wa...
# 29       [el, de, la, que, se, es, lo, no, muy, para]
# 30  [good, ok, no, not, okay, its, great, best, fa...
# 31  [junk, garbage, trash, crap, waste, complete, ...
# 32  [tripod, legs, the, to, it, is, for, but, this...
# 33  [cute, but, plastic, fur, cheap, daughter, it,...
# 34  [leather, is, not, real, genuine, it, cheap, t...
# 35  [stones, crystals, rhinestones, off, gems, bli...
# 36  [last, lasted, didnt, long, months, week, only...
# 37   [it, case, and, the, is, this, my, but, for, to]
# 38  [install, easy, to, installation, and, difficu...
# 39  [s10, s21, galaxy, for, the, fit, not, it, cas...
#
#                                   Representative_Docs
# 0   [i have had a casecrown same color and style o...
# 1   [the charger is a convenient size similar dime...
# 2   [i like the feel of the material but thats abo...
# 3   [this watch band was returned, i loved the loo...
# 4   [made of plastic feels very cheap it doesnt fe...
# 5   [if i could give this phone 0 stars i would le...
# 6   [it does not fit the phone, this case does not...
# 7   [updated dropped some stars because within les...
# 8   [we tried all the directions that came with th...
# 9   [horrible screen protector when i bought my ph...
# 10  [it broke after 2 weeks, broke after 1 use, it...
# 11  [stopped working after one use, i bought 4 of ...
# 12  [i was pretty sad when i received this phone c...
# 13  [i have only had this since february 2014 and ...
# 14  [it is so hard to press the side buttons with ...
# 15  [i just got an ipad and i want to paint on it ...
# 16  [put protector on bubbles never went away we k...
# 17               [it didnt fit, it didnt fit, it fit]
# 18  [what does two stars mean it means i dont like...
# 19  [would not stay in my air vent, will not stay ...
# 20               [didnt work, didnt work, didnt work]
# 21  [was not what i expected returned, sent back b...
# 22  [it has scratches all over after only a week o...
# 23  [the pop socket is super cute but its almost a...
# 24                      [flimsy, flimsy, very flimsy]
# 25  [not good quality, not good quality, not very ...
# 26  [not glass, not glass, not a screen protector ...
# 27  [works great not much more to say editing this...
# 28  [the cover did arrive on time but broke after ...
# 29  [pero no me gusto al momento de ponerle el pro...
# 30                     [not good, not good, not good]
# 31  [junk, junk, garbage junk cheap trash dont was...
# 32  [difficult to fit on the tripod i have, endura...
# 33  [cute but hard to take off, very cute but hard...
# 34  [not leather really cheap returned it, not gen...
# 35  [lost crystals right away looked nice but then...
# 36  [didnt last, it didnt last to long, didnt last...
# 37  [videoid5393bae69c3ea5825615492f73dbda52 thank...
# 38  [could not install, difficult to install, easy...
# 39  [this would have been a great case it came in ...

# %% [markdown]
# # 2. Topic mapping

# %%
df = df.drop(columns=['topic_id','topic_label'],errors='ignore')

# %%
topic_labels = {
    -1: "Noise",
    0: "Charging issues",
    1: "Ring/Card Slot Cases",
    2: "Wearable bands",
    3: "Phone cases",
    4: "Phone issue",
    5: "Case Fitting issues", #Redundant with topic 16
    6: "Mounts,Holder issue",
    7: "Fingerprints/screen protector",
    8: "Cracked screen/Display",
    9: "Broken item", # Redundant with topic 10
    10: "Item stopped working",
    11: "Case Color related",
    12: "Sound/Hearing issues",
    13: "Issue with buttons/Buttons not working",
    14: "Stylus/Pen issues",
    15: "Screen protector issue (bubble formation)",
    16: "Fitting issues", 
    17: "Camera/Camera lens issues",
    18: "Vent mounts/holder issues",
    19: "Item does not work", # Redundant with topic 10
    20: "Return related issue",
    21: "Scratch issues",
    22: "Popsockets",
    23: "Build Quality/Form Factor complaints",
    24: "Product Quality issues",
    25: "Glass Screen related issues",
    26: "Irrelevant",
    27: "Phone Covers/Protection",
    28: "Irrelevant",
    29: "Irrelevant",
    30: "Irrelevant",
    31: "Tripod issues",
    32: "Plastic product",
    33: "Not a genuine product",
    34: "Crystals lost",
    35: "Not reliable",
    36: "Irrelevant",
    37: "Installation issues",
    38: "Device Fitting issues" #Redundant with topic 16
}

# %%
df['topic_id'] = topic_model.topics_
df['topic_label'] = df['topic_id'].map(topic_labels)
print(df[['text','topic_id','topic_label']].head(10))
print(df['topic_label'].value_counts().head(15))
# Out:
#                                                 text  topic_id  \
# 0  Putting it on a night stand drawer or top of h...         7
# 1  A bit complicated to apply. Requires spraying ...         4
# 2  This product is cheaply made, some of the part...         6
# 3  I absolutely do not like this phone. Screen is...         0
# 4  Refurbished so I expected it to work well but ...         0
# 5                   WRONG CABLE. . .DID NOT USE. . .         0
# 6  I didn’t like this product because water got i...         3
# 7  Got it in the mail and was way too excited to ...         0
# 8  Fell apart right away.  Clamps get in the way ...        10
# 9  Within 2 weeks of using it fell off the phone ...         2
#
#                      topic_label
# 0  Fingerprints/screen protector
# 1                    Phone issue
# 2            Mounts,Holder issue
# 3                Charging issues
# 4                Charging issues
# 5                Charging issues
# 6                    Phone cases
# 7                Charging issues
# 8           Item stopped working
# 9                 Wearable bands
# topic_label
# Noise                            11173
# Charging issues                   4774
# Ring/Card Slot Cases              1573
# Wearable bands                    1527
# Phone cases                       1520
# Phone issue                       1478
# Case Fitting issues               1086
# Mounts,Holder issue                864
# Fingerprints/screen protector      791
# Cracked screen/Display             551
# Broken item                        544
# Item stopped working               465
# Case Color related                 417
# Sound/Hearing issues               401
# Irrelevant                         376
# Name: count, dtype: int64

# %%
print(df['topic_label'].isna().sum()) 
print(df['topic_id'].nunique())
# Out:
# 0
# 40

# %%
df.to_csv("../data/cleaned/cleaned_reviews.csv", index=False)

# %%
charging_complaints = df[df['topic_label'] == 'Charging issues'][['rating', 'text']].head(5)
print(charging_complaints)
# Out:
#     rating                                               text
# 5      2.0                   WRONG CABLE. . .DID NOT USE. . .
# 7      1.0  Got it in the mail and was way too excited to ...
# 12     2.0  I had one that lasted for about a year. I boug...
# 20     2.0  The USB port just broke loose the 3rx time I u...
# 36     1.0  UPDATE:  purchased  6/20/18  .....  it only ch...

# %% [markdown]
# ## Topic Modeling — BERTopic
#
# ### Configuration & Tuning
#
# | Version | min_topic_size | Topics | Noise Count | Noise % |
# |---------|---------------|--------|-------------|---------|
# | v1 | 50 | 79 | 11,173 | 37% |
# | v2 | 30 | 127 | 11,773 | 33% |
# | Final (reduced) | 50 → reduced | 40 | 11,834 | 39% |
#
# **Decision:** v1 with `reduce_topics(nr_topics=40)` selected — fewer, cleaner topics
# with slightly lower noise vs v2. 40 topics is actionable for a support routing system.
#
# **Why pre-computed embeddings?**
# Passed `sentence_embeddings.npy` directly to BERTopic — skips redundant embedding
# step, saves ~200 seconds per run. BERTopic ran UMAP + HDBSCAN only (58 seconds).
#
# ### Topic Quality
# - **34 actionable topics** covering: Charging Issues, Wearable Bands, Screen Protector
#   Bubbles, Fingerprint Reader, Stylus Issues, Car Vent Mounts, Camera Accessories, etc.
# - **5 irrelevant clusters** identified and labeled: Spanish reviews (topic 28),
#   meta-commentary (topic 26), generic bad reviews (topic 29, 30), bad cluster (topic 36)
# - **3 redundant topic pairs** noted as merge candidates for production:
#   - Topics 5, 16, 38 → all fitting-related
#   - Topics 9, 10, 19 → all broken/stopped working
#
# ### Topic Distribution (Top 5)
# | Topic | Count |
# |-------|-------|
# | Noise | 11,834 |
# | Charging Issues | 2,746 |
# | Ring/Card Slot Cases | 1,392 |
# | Wearable Bands | 1,062 |
# | Irrelevant | 877 |
#
# ### Known Limitations
# - **39% noise** — genuinely ambiguous short reviews ("Not working!", "One Star")
#   that lack distinctive vocabulary for clustering. These remain available for
#   semantic retrieval but are excluded from topic-based routing.
# - Some legitimate complaints fell into irrelevant clusters (e.g. row 2:
#   *"product is cheaply made, parts missing"* → topic 36/Irrelevant)
# - Non-English reviews (Spanish) formed their own cluster — not filtered in preprocessing
#
# ### Next Step
# Topic labels stored as `topic_id` and `topic_label` columns in `cleaned_review.csv`
# — will be used as metadata in ChromaDB (Phase 5) for filtered retrieval.

# %% [markdown]
# ## Topic Labelling Fix
#
# **Root cause**: `reduce_topics(nr_topics=40)` was called on topic_model, but the dataframe was populated using `topic_model.topics_` — which reflects the pre-reduction 79-topic assignment. The reduced topic IDs only live on the model object after `reduce_topics()` is called; they are not automatically written back. As a result, `cleaned_reviews.csv` was saved with 78 unique topic IDs instead of 40, and ChromaDB was ingested with those stale labels.
#
# **Detected when**: topic_centroids computed in Phase 6 returned 78 centroids instead of the expected 40.
#
# **Fix**: Re-ran the label assignment using the post-reduction topics, verified `df['topic_id'].nunique() == 40` and `df['topic_label'].isna().sum() == 0`, re-saved CSV, deleted and re-ingested ChromaDB collection.
#
# **Lesson**: After calling `reduce_topics()`, always re-extract topics via `topic_model.topics_` in the same cell, since the attribute is updated in-place. Verify with `nunique()` before saving.
